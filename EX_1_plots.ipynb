# %%
import matplotlib.pyplot as plt
lambda_values = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
srf_values = [0.6802, 0.6781,0.6728,  0.6711, 0.6756, 0.6646,0.6662, 0.6636, 0.6704, 0.6712]
srg_values = [0.6638, 0.6619, 0.6613, 0.6617,0.6621,0.6571, 0.6501, 0.6498,  0.6512, 0.6578]
src_values = [0.6832, 0.6795, 0.6751,0.6739, 0.6788, 0.6715, 0.6707,  0.6709, 0.6711,0.6702]

# plot the values
plt.plot(lambda_values, srf_values, label='SR-F')
plt.plot(lambda_values, srg_values, label='SR-G')
plt.plot(lambda_values, src_values, label='SR-C')
plt.axhline(y=0.6466, color='r', linestyle='-', label='Base GAT')

# add axis labels and a legend
plt.xlabel('Lambda')
plt.ylabel('Test accuracy')
plt.title("Performance on CiteSeer dataset")
plt.legend()

# show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
lambda_values = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
sr_f_values = [0.7355, 0.7306, 0.7219, 0.7270, 0.7155, 0.7175, 0.7211, 0.7211, 0.7211, 0.7211]
sr_g_values = [0.7212, 0.7201, 0.7113, 0.7102, 0.71189, 0.7105, 0.7096, 0.7131, 0.7131, 0.7118]
sr_c_values = [0.7471, 0.7416, 0.7412, 0.7408, 0.7401, 0.7344, 0.7304, 0.7301, 0.7256, 0.7237]

# create the plot
fig, ax = plt.subplots()
ax.plot(lambda_values, sr_f_values, label="SR-F")
ax.plot(lambda_values, sr_g_values, label="SR-G")
ax.plot(lambda_values, sr_c_values, label="SR-C")
plt.axhline(y=0.6956, color='r', linestyle='-', label='Base GAT')

# add axis labels and a legend
plt.xlabel('Lambda')
plt.ylabel('Test accuracy')
plt.title("Performance on Cora dataset")
plt.legend()


# show the plot
plt.show()

# %%
lambda_values = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
sr_f_values = [0.7782,0.7770,0.7763,0.7762,0.7761,0.770,0.7703,0.7688,0.7686,0.7650]
sr_g_values = [0.7730,0.7721,0.7725,0.7710,0.7686,0.7629,0.7652,0.7638,0.7623,0.7650]
sr_c_values = [0.7933,0.7919,0.7871,0.7870,0.7820,0.7833,0.7793,0.7801,0.7751,0.7725]

# create the plot
fig, ax = plt.subplots()
ax.plot(lambda_values, sr_f_values, label="SR-F")
ax.plot(lambda_values, sr_g_values, label="SR-G")
ax.plot(lambda_values, sr_c_values, label="SR-C")
plt.axhline(y=0.7620, color='r', linestyle='-', label='Base GAT')

# add axis labels and a legend
plt.xlabel('Lambda')
plt.ylabel('Test accuracy')
plt.title("Performance on PubMed dataset")
plt.legend()


# show the plot
plt.show()
